# %% [markdown]
# Question 1:
# Use your data to perform a clustering model. Justify the choice of your algorithm and add the column with
# the outcome on the dataset to perform two classification models. Determine which one would be the best one
# in this case. Summarize your findings, discussing the model's performance and any insights gained from the
# analysis. (20 marks)

# %% [markdown]
# Pregunta 1:
#
# Utiliza tus datos para realizar un modelo de clustering. Justifica la elección de tu algoritmo y añade una columna con el resultado en el conjunto de datos para realizar dos modelos de clasificación. Determina cuál es el mejor en este caso.
#
# Resume tus hallazgos, discutiendo el rendimiento del modelo y cualquier información obtenida del análisis. (20 puntos)
